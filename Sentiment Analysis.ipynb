# %%
import requests
from bs4 import BeautifulSoup
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# Function to fetch headlines from Yahoo Finance
def fetch_headlines():
    url = "https://finance.yahoo.com/"
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    headlines = soup.find_all('h3')
    return [headline.get_text() for headline in headlines if headline.get_text()]

# Function for sentiment analysis using NLTK's Vader
def analyze_sentiment(headlines):
    sid = SentimentIntensityAnalyzer()
    sentiments = []
    for headline in headlines:
        sentiment_score = sid.polarity_scores(headline)
        sentiments.append((headline, sentiment_score))
    return sentiments

# Main function
def main():
    headlines = fetch_headlines()
    sentiments = analyze_sentiment(headlines)
    for headline, sentiment in sentiments:
        print(headline)
        print("Sentiment Score:", sentiment)
        print()

if __name__ == "__main__":
    main()
# Out:
# S&P 5005,201.59-4.22(-0.08%)
# Sentiment Score: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Dow 3039,041.16-129.08(-0.33%)
# Sentiment Score: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Nasdaq16,245.92+5.47(+0.03%)
# Sentiment Score: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Russell 20002,078.25+13.21(+0.64%)
# Sentiment Score: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Crude Oil85.45+0.30(+0.35%)
# Sentiment Score: {'neg': 0.787, 'neu': 0.213, 'pos': 0.0, 'compound': -0.5719}
#
# Gold2,316.00+34.20(+1.50%)
# Sentiment Score: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Hunt for Iger's successor now kicks into high gear
# Sentiment Score: {'neg': 0.0, 'neu': 0.808, 'pos': 0.192, 'compound': 0.2263}
#
# Powell still expects Fed to lower rates this year
# Sentiment Score: {'neg': 0.216, 'neu': 0.784, 'pos': 0.0, 'compound': -0.296}
#
# Stocks rebound after rough start to Q2
# Sentiment Score: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# What has happened after the Fed cut rates in a strong economy
# Sentiment Score: {'neg': 0.146, 'neu': 0.625, 'pos': 0.229, 'compound': 0.296}
#
# 'Triple-digit oil prices are not that far': Analyst
# Sentiment Score: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Americans' goals for retirement, savings are miles apart
# Sentiment Score: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Key Fed officials still expect 3 rate cuts this year
# Sentiment Score: {'neg': 0.216, 'neu': 0.784, 'pos': 0.0, 'compound': -0.296}
#
# US labor market remains 'quite healthy'
# Sentiment Score: {'neg': 0.0, 'neu': 0.626, 'pos': 0.374, 'compound': 0.4576}
#
# Nvidia Stock and AMD Stock: You Won't Believe My Shocking Conclusion
# Sentiment Score: {'neg': 0.0, 'neu': 0.816, 'pos': 0.184, 'compound': 0.3089}
#
# New Mom Tells Dave Ramsey Her Husband Makes $950K But Won't Let Her Stay Home — 'I Think You Can Probably Freaking Struggle Through'
# Sentiment Score: {'neg': 0.241, 'neu': 0.759, 'pos': 0.0, 'compound': -0.7684}
#
# Trump Sues Truth Social Company Co-Founders to Zero Them Out
# Sentiment Score: {'neg': 0.0, 'neu': 0.796, 'pos': 0.204, 'compound': 0.3182}
#
# I'm Going to Get $2,800 Per Month in Social Security. How Do I Reduce My Taxes on It?
# Sentiment Score: {'neg': 0.0, 'neu': 0.87, 'pos': 0.13, 'compound': 0.34}
#
# US may be forced to delay interest rate cuts, warns Powell
# Sentiment Score: {'neg': 0.497, 'neu': 0.335, 'pos': 0.168, 'compound': -0.5994}
#
# DJT Stock Slips. Trump Is Suing Co-Founders of the Truth Social Parent.
# Sentiment Score: {'neg': 0.146, 'neu': 0.694, 'pos': 0.16, 'compound': 0.0516}
#
# As Norway nears major victory over gas-powered cars, Ireland joins EV winter with drivers falling prey to ‘misinformation’
# Sentiment Score: {'neg': 0.086, 'neu': 0.914, 'pos': 0.0, 'compound': -0.1531}
#
# Dow Jones Dives As Donald Trump Stock Soars; Cathie Wood Loads Up On This Stock Amid 44% Plunge
# Sentiment Score: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Musk Says Tesla Could Be the World’s Most Valuable Stock. Now It’s Just a Car Company.
# Sentiment Score: {'neg': 0.0, 'neu': 0.805, 'pos': 0.195, 'compound': 0.5256}
#
# 2 Beaten-Down Dividend Stocks With Yields Above 6% to Buy Now and Hold Forever
# Sentiment Score: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
